# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_baseball.csv')

# %%
# Vertical Apporach Angle (degrees)
def calculate_vaa_physics(row):
    vy0 = row['vy0']  # y-velocity at 50ft (ft/s)
    ay = row['ay']    # y-acceleration (ft/s²)
    vz0 = row['vz0']  # z-velocity at 50ft (ft/s)
    az = row['az']    # z-acceleration (ft/s²)
    
    # Distance from 50ft mark to home plate (50ft)
    y0_minus_yf = 50
    
    vy_f = -np.sqrt(vy0**2 - (2 * ay * y0_minus_yf))
    t = (vy_f - vy0) / ay
    vz_f = vz0 + (az * t)
    vaa = -np.degrees(np.arctan(vz_f / vy_f))
    return round(vaa, 2)

df['VAA'] = df.apply(calculate_vaa_physics, axis=1)

# Horizontal Approach Angle (degrees)
# HAA = arctan(horizontal movement / distance from 50ft to home)
df['HAA'] = np.degrees(np.arctan(df['pfx_x'] / 50)).round(2)


# If spin_axis is stored in degrees
df['spin_axis_rad'] = np.radians(df['spin_axis'])  # Correct conversion

# Spin Efficiency (estimated)
# Spin axis adjustment: 0° = topspin, 180° = backspin, 90° = sidespin
df['spin_efficiency'] = np.abs(np.sin(df['spin_axis_rad'])).round(2)

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2025-03-25           98.3          -2.47           5.22
# 1         SI  2025-03-25           98.6          -2.48           5.11
# 2         SI  2025-03-25          100.7          -2.27           5.29
# 3         SI  2025-03-25           99.7          -2.22           5.26
# 4         SI  2025-03-25           98.6          -2.44           5.19
#
#     pitcher_name  batter  pitcher     events      description  ...  \
# 0  Faherty, Jake  665998   801619  field_out    hit_into_play  ...
# 1  Faherty, Jake  665998   801619        NaN    called_strike  ...
# 2  Faherty, Jake  672724   801619  field_out    hit_into_play  ...
# 3  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
# 4  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
#
#    batter_days_until_next_game  api_break_z_with_gravity  api_break_x_arm  \
# 0                          NaN                      1.23             1.44
# 1                          NaN                      1.07             1.35
# 2                          NaN                      1.25             1.02
# 3                          NaN                      1.22             0.82
# 4                          NaN                      0.99             1.11
#
#    api_break_x_batter_in  arm_angle      batter_name   VAA   HAA  \
# 0                  -1.44        NaN  Munguia, Ismael -5.36 -1.65
# 1                  -1.35        NaN  Munguia, Ismael -4.64 -1.55
# 2                   1.02        NaN   Peraza, Oswald -4.90 -1.17
# 3                   0.82        NaN   Peraza, Oswald -3.55 -0.94
# 4                   1.11        NaN   Peraza, Oswald -4.03 -1.27
#
#   spin_axis_rad spin_efficiency
# 0      4.101524            0.82
# 1      4.118977            0.83
# 2      4.049164            0.79
# 3      4.084070            0.81
# 4      4.049164            0.79
#
# [5 rows x 118 columns]

# %%
# Calculate overall averages across all years
league_avg_pfx_z = df.groupby('pitch_type')['pfx_z'].transform('mean')
league_avg_pfx_x = df.groupby('pitch_type')['pfx_x'].transform('mean')

# Break+
df['Vertical_Break'] = (df['pfx_z'] / league_avg_pfx_z) * 100
df['Horizontal_Break'] = (df['pfx_x'] / league_avg_pfx_x) * 100


df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2025-03-25           98.3          -2.47           5.22
# 1         SI  2025-03-25           98.6          -2.48           5.11
# 2         SI  2025-03-25          100.7          -2.27           5.29
# 3         SI  2025-03-25           99.7          -2.22           5.26
# 4         SI  2025-03-25           98.6          -2.44           5.19
#
#     pitcher_name  batter  pitcher     events      description  ...  \
# 0  Faherty, Jake  665998   801619  field_out    hit_into_play  ...
# 1  Faherty, Jake  665998   801619        NaN    called_strike  ...
# 2  Faherty, Jake  672724   801619  field_out    hit_into_play  ...
# 3  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
# 4  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
#
#    api_break_x_arm  api_break_x_batter_in  arm_angle      batter_name   VAA  \
# 0             1.44                  -1.44        NaN  Munguia, Ismael -5.36
# 1             1.35                  -1.35        NaN  Munguia, Ismael -4.64
# 2             1.02                   1.02        NaN   Peraza, Oswald -4.90
# 3             0.82                   0.82        NaN   Peraza, Oswald -3.55
# 4             1.11                   1.11        NaN   Peraza, Oswald -4.03
#
#     HAA spin_axis_rad spin_efficiency Vertical_Break Horizontal_Break
# 0 -1.65      4.101524            0.82     173.517810       278.507995
# 1 -1.55      4.118977            0.83     196.150568       261.101245
# 2 -1.17      4.049164            0.79     150.885052       197.276496
# 3 -0.94      4.084070            0.81     161.447006       158.594830
# 4 -1.27      4.049164            0.79     206.712522       214.683246
#
# [5 rows x 120 columns]

# %%
# Define swing-and-miss (whiff) events
whiff_events = ['swinging_strike', 'swinging_strike_blocked', 'missed_bunt']
df['is_whiff'] = df['description'].isin(whiff_events).astype(int)

# Define strikes (including fouls)
strike_events = ['called_strike', 'swinging_strike', 'foul', 'foul_tip']
df['is_strike'] = df['description'].isin(strike_events).astype(int)

df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2025-03-25           98.3          -2.47           5.22
# 1         SI  2025-03-25           98.6          -2.48           5.11
# 2         SI  2025-03-25          100.7          -2.27           5.29
# 3         SI  2025-03-25           99.7          -2.22           5.26
# 4         SI  2025-03-25           98.6          -2.44           5.19
#
#     pitcher_name  batter  pitcher     events      description  ...  arm_angle  \
# 0  Faherty, Jake  665998   801619  field_out    hit_into_play  ...        NaN
# 1  Faherty, Jake  665998   801619        NaN    called_strike  ...        NaN
# 2  Faherty, Jake  672724   801619  field_out    hit_into_play  ...        NaN
# 3  Faherty, Jake  672724   801619        NaN  swinging_strike  ...        NaN
# 4  Faherty, Jake  672724   801619        NaN  swinging_strike  ...        NaN
#
#        batter_name   VAA   HAA  spin_axis_rad spin_efficiency Vertical_Break  \
# 0  Munguia, Ismael -5.36 -1.65       4.101524            0.82     173.517810
# 1  Munguia, Ismael -4.64 -1.55       4.118977            0.83     196.150568
# 2   Peraza, Oswald -4.90 -1.17       4.049164            0.79     150.885052
# 3   Peraza, Oswald -3.55 -0.94       4.084070            0.81     161.447006
# 4   Peraza, Oswald -4.03 -1.27       4.049164            0.79     206.712522
#
#   Horizontal_Break is_whiff is_strike
# 0       278.507995        0         0
# 1       261.101245        0         1
# 2       197.276496        0         0
# 3       158.594830        1         1
# 4       214.683246        1         1
#
# [5 rows x 122 columns]

# %%
def categorize_zone(row):
    if row['plate_z'] < 2.5:
        vertical = 'low'
    else:
        vertical = 'high'
    
    if row['plate_x'] < -0.5:
        horizontal = 'away'
    elif row['plate_x'] > 0.5:
        horizontal = 'inside'
    else:
        horizontal = 'middle'
    
    return f"{vertical}_{horizontal}"

df['zone_category'] = df.apply(categorize_zone, axis=1)

df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2025-03-25           98.3          -2.47           5.22
# 1         SI  2025-03-25           98.6          -2.48           5.11
# 2         SI  2025-03-25          100.7          -2.27           5.29
# 3         SI  2025-03-25           99.7          -2.22           5.26
# 4         SI  2025-03-25           98.6          -2.44           5.19
#
#     pitcher_name  batter  pitcher     events      description  ...  \
# 0  Faherty, Jake  665998   801619  field_out    hit_into_play  ...
# 1  Faherty, Jake  665998   801619        NaN    called_strike  ...
# 2  Faherty, Jake  672724   801619  field_out    hit_into_play  ...
# 3  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
# 4  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
#
#        batter_name   VAA   HAA  spin_axis_rad  spin_efficiency Vertical_Break  \
# 0  Munguia, Ismael -5.36 -1.65       4.101524             0.82     173.517810
# 1  Munguia, Ismael -4.64 -1.55       4.118977             0.83     196.150568
# 2   Peraza, Oswald -4.90 -1.17       4.049164             0.79     150.885052
# 3   Peraza, Oswald -3.55 -0.94       4.084070             0.81     161.447006
# 4   Peraza, Oswald -4.03 -1.27       4.049164             0.79     206.712522
#
#   Horizontal_Break is_whiff is_strike zone_category
# 0       278.507995        0         0      low_away
# 1       261.101245        0         1    low_middle
# 2       197.276496        0         0    low_middle
# 3       158.594830        1         1   high_middle
# 4       214.683246        1         1     high_away
#
# [5 rows x 123 columns]

# %%
# Pitcher's cumulative whiff rate (up to current game)
df['pitcher_whiff_rate'] = df.groupby(['pitcher', 'pitch_type'])['is_whiff'] \
    .transform(lambda x: x.expanding().mean().shift(1))

# Batter's weakness against pitch types (up to current game)
df['batter_whiff_rate'] = df.groupby(['batter', 'pitch_type'])['is_whiff'] \
    .transform(lambda x: x.expanding().mean().shift(1))

# League-average whiff rates
league_whiff_rates = df.groupby('pitch_type')['is_whiff'].mean().to_dict()
df['league_whiff_rate'] = df['pitch_type'].map(league_whiff_rates)

df['pitcher_whiff_rate'] = df['pitcher_whiff_rate'].fillna(df['league_whiff_rate'])
df['batter_whiff_rate'] = df['batter_whiff_rate'].fillna(df['league_whiff_rate'])

df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2025-03-25           98.3          -2.47           5.22
# 1         SI  2025-03-25           98.6          -2.48           5.11
# 2         SI  2025-03-25          100.7          -2.27           5.29
# 3         SI  2025-03-25           99.7          -2.22           5.26
# 4         SI  2025-03-25           98.6          -2.44           5.19
#
#     pitcher_name  batter  pitcher     events      description  ...  \
# 0  Faherty, Jake  665998   801619  field_out    hit_into_play  ...
# 1  Faherty, Jake  665998   801619        NaN    called_strike  ...
# 2  Faherty, Jake  672724   801619  field_out    hit_into_play  ...
# 3  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
# 4  Faherty, Jake  672724   801619        NaN  swinging_strike  ...
#
#    spin_axis_rad  spin_efficiency  Vertical_Break  Horizontal_Break  is_whiff  \
# 0       4.101524             0.82      173.517810        278.507995         0
# 1       4.118977             0.83      196.150568        261.101245         0
# 2       4.049164             0.79      150.885052        197.276496         0
# 3       4.084070             0.81      161.447006        158.594830         1
# 4       4.049164             0.79      206.712522        214.683246         1
#
#   is_strike zone_category pitcher_whiff_rate batter_whiff_rate  \
# 0         0      low_away           0.057974          0.057974
# 1         1    low_middle           0.000000          0.000000
# 2         0    low_middle           0.000000          0.057974
# 3         1   high_middle           0.000000          0.000000
# 4         1     high_away           0.250000          0.500000
#
#   league_whiff_rate
# 0          0.057974
# 1          0.057974
# 2          0.057974
# 3          0.057974
# 4          0.057974
#
# [5 rows x 126 columns]

# %%
df_new = df[[
    'game_date', 'game_type', 'pitcher', 'pitcher_name',
    'batter', 'batter_name',
    'pitch_type', 'pitch_name', 'events', 'description', 'stand', 'p_throws',
    'release_speed', 'release_spin_rate', 'effective_speed', 
    'release_pos_x', 'release_pos_y', 'release_pos_z', 
    'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 
    'pfx_x', 'pfx_z',
    'plate_x', 'plate_z', 'zone', 
    'type', 'hit_location', 'bb_type', 'balls', 'strikes', 
    'hc_x', 'hc_y', 'launch_speed', 'launch_angle',
    'launch_speed_angle', 'arm_angle', 'VAA', 'HAA',
    'spin_axis', 'spin_efficiency',
    'Vertical_Break', 'Horizontal_Break',
    'is_whiff', 'is_strike', 'zone_category', 
    'pitcher_whiff_rate', 'batter_whiff_rate', 'league_whiff_rate'
]].copy()

# %%
df_new.head()
# Out:
#     game_date game_type  pitcher   pitcher_name  batter      batter_name  \
# 0  2025-03-25         S   801619  Faherty, Jake  665998  Munguia, Ismael
# 1  2025-03-25         S   801619  Faherty, Jake  665998  Munguia, Ismael
# 2  2025-03-25         S   801619  Faherty, Jake  672724   Peraza, Oswald
# 3  2025-03-25         S   801619  Faherty, Jake  672724   Peraza, Oswald
# 4  2025-03-25         S   801619  Faherty, Jake  672724   Peraza, Oswald
#
#   pitch_type pitch_name     events      description  ... spin_axis  \
# 0         SI     Sinker  field_out    hit_into_play  ...     235.0
# 1         SI     Sinker        NaN    called_strike  ...     236.0
# 2         SI     Sinker  field_out    hit_into_play  ...     232.0
# 3         SI     Sinker        NaN  swinging_strike  ...     234.0
# 4         SI     Sinker        NaN  swinging_strike  ...     232.0
#
#   spin_efficiency  Vertical_Break  Horizontal_Break  is_whiff  is_strike  \
# 0            0.82      173.517810        278.507995         0          0
# 1            0.83      196.150568        261.101245         0          1
# 2            0.79      150.885052        197.276496         0          0
# 3            0.81      161.447006        158.594830         1          1
# 4            0.79      206.712522        214.683246         1          1
#
#    zone_category  pitcher_whiff_rate  batter_whiff_rate  league_whiff_rate
# 0       low_away            0.057974           0.057974           0.057974
# 1     low_middle            0.000000           0.000000           0.057974
# 2     low_middle            0.000000           0.057974           0.057974
# 3    high_middle            0.000000           0.000000           0.057974
# 4      high_away            0.250000           0.500000           0.057974
#
# [5 rows x 52 columns]

# %%
df_new.to_csv('final_baseball.csv', index=False)
